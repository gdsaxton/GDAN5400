# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gdsaxton/GDAN5400/blob/main/Coding%20Assignment%201/GDAN5400%20-%20Coding%20Assignment%201.ipynb)

# %% [markdown]
# This notebook provides recipes for loading and saving data from external sources in Colab.

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
# Out:
# Current date and time :  2025-01-05 23:37:45
#
# CPU times: user 274 µs, sys: 73 µs, total: 347 µs
# Wall time: 331 µs

# %% [markdown]
# # Read in Data

# %%
# !wget 'https://github.com/gdsaxton/SNA_Example/blob/main/Co-Author%20University%20Network.csv?raw=true'

# %%
import os
os.listdir()

# %%
os.rename('Co-Author University Network.csv?raw=true', 'Co-Author University Network.csv')

# %%
os.listdir()

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df = pd.read_csv('Co-Author University Network.csv')
print('# of columns:', len(df.columns))
print('# of observations:', len(df))

# %% [markdown]
# # Inspect the Data
#
# - **Basic inspection commands:**
#   - View the first few rows of the dataset:
#     ```python
#     print(df.head())
#     ```
#   - Check the structure and data types:
#     ```python
#     print(df.info())
#     ```
#   - Get a summary of numerical columns:
#     ```python
#     print(df.describe())
#     ```

# %%
# Inspect the dataset
print("First 5 rows:")
df.head()

# %%
print("Print all column names:\n")
print(df.columns)

# %%
print("Display the structure and data types for all variables.\n")
df.info()

# %%
print("Display summary statistics for all numeric columns:")
df.describe().T

# %% [markdown]
# # Local file system
# ### Uploading files from your local file system
#
# `files.upload` returns a dictionary of the files which were uploaded.
# The dictionary is keyed by the file name and values are the data which were uploaded.
#
# ```python
# #Run this code to upload the file:
# from google.colab import files
# uploaded = files.upload()  # This will prompt you to upload the file
# ```
#
# ```python
# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))
# ```

# %%
#Once uploaded, you can open the file using pandas:
import pandas as pd
df = pd.read_excel('final_insurance_fraud.xlsx')

# %% [markdown]
# ### Option 2: Mount Google Drive Locally
#
# The example below shows how to mount your Google Drive on your runtime using an authorization code, and how to write and read files there. Once executed, you will be able to see the new file (`foo.txt`) at [https://drive.google.com/](https://drive.google.com/).
#
# This only supports reading, writing, and moving files; to programmatically modify sharing settings or other metadata, use one of the other options below.
#
# **Note:** When using the 'Mount Drive' button in the file browser, no authentication codes are necessary for notebooks that have only been edited by the current user.
#
# To access an Excel file stored in your Google Drive:
#
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
# ```
#
# Access the file:
#
# ```python
# import pandas as pd
# file_path = '/content/drive/My Drive/your_file.xlsx'
# df = pd.read_excel(file_path)
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
file_path = '/content/drive/My Drive/final_insurance_fraud.xlsx'
df = pd.read_excel(file_path)

# %% [markdown]
# #### Option 2b: Alternative

# %%
with open('/content/drive/My Drive/final_insurance_fraud.xlsx', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/final_insurance_fraud.xlsx

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')

# %% [markdown]
# All changes made in this colab session should now be visible in Drive.

# %% [markdown]
# ### Option 3: Download from an Online URL
# If the Excel file is hosted online:
# 1. Use `requests` to fetch the file
#
# ```python
# import pandas as pd
# import requests
#
# url = 'http://example.com/your_file.xlsx'
# response = requests.get(url)
# with open('temp_file.xlsx', 'wb') as f:
#     f.write(response.content)
#
# df = pd.read_excel('temp_file.xlsx')
# ```

# %%
import pandas as pd
import requests

# NOTE: replace `https://github.com/` with `https://raw.githubusercontent.com`
# https://github.com/gdsaxton/GDAN5400/blob/main/Coding%20Assignment%201/final_insurance_fraud.xlsx
url = 'https://raw.githubusercontent.com/gdsaxton/GDAN5400/main/Coding%20Assignment%201/final_insurance_fraud.xlsx'

# Download the file
response = requests.get(url)
with open('final_insurance_fraud.xlsx', 'wb') as f:
    f.write(response.content)

# Load the Excel file
df = pd.read_excel('final_insurance_fraud.xlsx', engine='openpyxl')

df.head()
# Out:
#    Policy Number  Claim number   Surname  Forenames               Occupation  \
# 0   3.989062e+09    6957097359    Bryant   Penelope           Civil Engineer
# 1   6.685581e+09      72789078      Moon   Brooklyn      Mechanical Engineer
# 2   3.681223e+09    1484217434  Delacruz     Meghan           Civil Engineer
# 3   7.523109e+09    1733099850    Tanner     Amelia           Food Scientist
# 4   5.944314e+09    5948167287   Sherman  Alejandra  Radiologic Technologist
#
#    House/Apartment Number Street Address   Latitude  Longitude  Zip Code  ...  \
# 0                     777   Maplewood Dr  41.997723  -88.68515     60178  ...
# 1                     777   Maplewood Dr  41.997723  -88.68515     60178  ...
# 2                     868   Maplewood Dr  41.997723  -88.68515     60178  ...
# 3                      56   Maplewood Dr  41.997723  -88.68515     60178  ...
# 4                     977   Maplewood Dr  41.997723  -88.68515     60178  ...
#
# ...

# %% [markdown]
# ### Option 3: WGET

# %%
# !wget 'https://github.com/gdsaxton/SNA_Example/blob/main/Co-Author%20University%20Network.csv?raw=true'

# %%
url = 'https://raw.githubusercontent.com/gdsaxton/GDAN5400/main/Coding%20Assignment%201/final_insurance_fraud.xlsx'

# %%
# !wget url
# Out:
# --2025-01-05 23:30:23--  http://url/
# Resolving url (url)... failed: nodename nor servname provided, or not known.
# wget: unable to resolve host address 'url'

# %%
# !wget 'https://github.com/gdsaxton/GDAN5400/blob/main/Coding%20Assignment%201/final_insurance_fraud.xlsx?raw=true'
# Out:
# --2025-01-05 23:31:09--  https://github.com/gdsaxton/GDAN5400/blob/main/Coding%20Assignment%201/final_insurance_fraud.xlsx?raw=true
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/gdsaxton/GDAN5400/raw/refs/heads/main/Coding%20Assignment%201/final_insurance_fraud.xlsx [following]
# --2025-01-05 23:31:09--  https://github.com/gdsaxton/GDAN5400/raw/refs/heads/main/Coding%20Assignment%201/final_insurance_fraud.xlsx
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gdsaxton/GDAN5400/refs/heads/main/Coding%20Assignment%201/final_insurance_fraud.xlsx [following]
# --2025-01-05 23:31:09--  https://raw.githubusercontent.com/gdsaxton/GDAN5400/refs/heads/main/Coding%20Assignment%201/final_insurance_fraud.xlsx
# ...

# %%
import os
os.listdir()
# Out:
# ['Social Media and Nonprofits - Looking for Cases for Vignettes.ipynb',
#  'IRS 990 e-File Preparer Data (6c) -- Collapse *Preparer Firms* for initial disambiguation (REDO, keep original firm name and city, collapse also by state).ipynb',
#  'IRS 990 e-File Preparer Study (2) - Read in Controls and Select Schedules.ipynb',
#  'IRS Form 990 e-File Data (8a) -- Identify and Drop Duplicate Org-Year Filings.ipynb',
#  'EVENT STUDY GENERATOR - SEC Filings and Cumulative Abnormal Tweeting.ipynb',
#  'LLM -AI - ChatGTP - Text Embedding Approach.ipynb',
#  "Cashtag Study - S&P (1b) - Download (with GNIP 'rules' code).ipynb",
#  'Tutorial - Set up iPython and Read in Data.ipynb',
#  'MLB.ipynb',
#  'IRS 990 e-File Data -- Compensation (3b) -- Combine, Flatten, and Parse Part VII - Section A.ipynb',
#  "Attention - Chapter 4 (K) - Model Selection ('Bivariate' ) -- and add missing values for 3 financial variables (plus checking for which vars included in all 3 f.s. stages).ipynb",
# ...

# %%
os.rename('final_insurance_fraud.xlsx?raw=true', 'final_insurance_fraud.xlsx?raw=true')

# %%
# %%time
import datetime
print ("Current date and time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), '\n')
df = pd.read_excel('/Users/gsaxton/Dropbox/ipython_notebooks/final_insurance_fraud.xlsx?raw=true')
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
df[:]
# Out:
# Current date and time :  2025-01-05 23:33:46
#
# # of columns: 31
# # of observations: 424
# CPU times: user 101 ms, sys: 2.6 ms, total: 103 ms
# Wall time: 103 ms
#      Policy Number  Claim number   Surname  Forenames  \
# 0     3.989062e+09    6957097359    Bryant   Penelope
# 1     6.685581e+09      72789078      Moon   Brooklyn
# 2     3.681223e+09    1484217434  Delacruz     Meghan
# 3     7.523109e+09    1733099850    Tanner     Amelia
# 4     5.944314e+09    5948167287   Sherman  Alejandra
# ..             ...           ...       ...        ...
# 419   8.153783e+09    2130284803   Fischer    Clinton
# 420   7.324928e+09    4009590908    Durham    Quinton
# 421   3.317300e+09    8879355124      Dunn     Parker
# 422   2.263619e+09    5724332778    Reeves     Tavian
# 423   3.437901e+09    1648265492     Weber     Sutton
#
#                   Occupation  House/Apartment Number Street Address  \
# 0             Civil Engineer                     777   Maplewood Dr
# ...

# %% [markdown]
# # Saving Files
#    - [This would be the ``Output`` tool in Alteryx]
#    - Export the cleaned dataset to a new `CSV` file.
#    - Example:
#      ```python
#      combined.to_csv('cleaned_roof_insurance_claims.csv', index=False)
#      ```

# %% [markdown]
# ### Option 1: Save to Your Google Drive

# %%
# Mount your Google Drive (should be already mounted above)
from google.colab import drive
drive.mount('/content/drive')

# %%
# Path to save the file in Google Drive
file_path = '/content/drive/My Drive/cleaned_roof_insurance_claims.csv'

# Save the DataFrame as a CSV file
df.to_csv(file_path, index=False)

print(f"File saved to {file_path}")

# %% [markdown]
# ### Option 2: Save and Download the File to Your Computer
# 1. Save the DataFrame as a CSV File.
# Use pandas to save the DataFrame to a CSV file in the Colab environment:

# %%
df.to_csv('cleaned_roof_insurance_claims.csv', index=False)

# %% [markdown]
# 2. Download the File to Your Computer.
# After saving the file, use the following code to download it:

# %%
from google.colab import files

# Download the file
files.download('cleaned_roof_insurance_claims.csv')
